# %%
from datetime import datetime, date

import matplotlib.pyplot as plt
import numpy as np

import sklearn.linear_model
import sklearn.model_selection
import pandas as pd
import yfinance as yfin

# %%
start = datetime(2022, 1, 5)
end = datetime.today()
df_aapl = yfin.download("AAPL", start, end)
df_fb = yfin.download("META", start, end)
df_gold = yfin.download("GLD", start, end)
df_aapl.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2026-05-05  284.179993  284.570007  276.500000  276.929993  49311700
# 2026-05-06  287.510010  288.029999  281.070007  281.920013  58336100
# 2026-05-07  287.440002  292.130005  285.779999  289.269989  45224300
# 2026-05-08  293.320007  294.760010  290.000000  290.010010  52631200
# 2026-05-11  292.679993  293.880005  290.230011  291.979004  39366022

# %%
df_aapl.columns = df_aapl.columns.droplevel(1)
df_aapl.columns
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')

# %%
df_aapl['SMA'] = df_aapl['Close'].rolling(window=14).mean()
df_aapl['SMA50'] = df_aapl['Close'].rolling(window=50).mean()
df_aapl['Close'].plot(figsize=(15,6), color="orange")
df_aapl['SMA'].plot(figsize=(15,6), color="blue")
df_aapl['SMA50'].plot(figsize=(15,6), color="green")
plt.show()
